# %%
rn=1
1=49
==61
n=110
r=114

# %%
x=114
y=110
z=61
p=49
(((((((x*17)%256+y)*17)%256+z)*17)%256+p)*17)%256
# Out:
# 30

# %%
line="rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7"
ex=line.split(',')
ex
# Out:
# ['rn=1',
#  'cm-',
#  'qp=3',
#  'cm=2',
#  'qp-',
#  'pc=4',
#  'ot=9',
#  'ab=5',
#  'pc-',
#  'pc=6',
#  'ot=7']

# %%
with open(r'C:\Users\SA012547\Documents\advent_of_code_2023\day15.txt') as f:
    line = f.readlines()

# %%
ascii_dic={x: chr(x) for x in range(0,128)}
inv_map = {v: k for k, v in ascii_dic.items()}
# inv_map

# %%
ex=line[0].split(',')

# %%
[inv_map[x]for x in ex[0]]
# Out:
# [100, 99, 102, 61, 51]

# %%
# on récupère la valeur de chaque caractere
list_value=[[inv_map[x]for x in ex[y]] for y in range(len(ex))]
# list_value

# %%
# 146, 0, 13, 30

# %%
l_tt = []
# list_value=[[114, 110, 61, 49]]
for v in range(len(list_value)):
    print(list_value[v])
    c_v = 0
    for n in range(len(list_value[v])):
        print(list_value[v][n])
        value_car =list_value[v][n]+c_v
#         print('vc', value_car)
#         value_car = c_v + value_car 
        c_v = value_car*17%256 
#         print('cv', c_v)
    l_tt.append(c_v)    
l_tt
# Out:
# [100, 99, 102, 61, 51]
# 100
# 99
# 102
# 61
# 51
# [104, 112, 61, 57]
# 104
# 112
# 61
# 57
# [107, 106, 102, 104, 120, 102, 45]
# 107
# 106
# 102
# 104
# 120
# 102
# 45
# [104, 112, 109, 118, 114, 103, 45]
# 104
# 112
# 109
# 118
# 114
# 103
# 45
# [112, 110, 98, 61, 55]
# 112
# 110
# 98
# 61
# 55
# [122, 120, 122, 45]
# 122
# 120
# 122
# 45
# [118, 114, 109, 116, 61, 52]
# 118
# 114
# 109
# 116
# 61
# 52
# [103, 104, 114, 120, 61, 55]
# 103
# 104
# 114
# 120
# 61
# 55
# [102, 122, 45]
# 102
# 122
# 45
# [118, 100, 120, 45]
# 118
# 100
# 120
# 45
# [112, 98, 102, 116, 45]
# 112
# 98
# 102
# 116
# 45
# [115, 120, 108, 122, 61, 55]
# 115
# 120
# 108
# 122
# 61
# 55
# [112, 100, 104, 45]
# 112
# 100
# 104
# 45
# [98, 100, 109, 61, 51]
# 98
# 100
# 109
# 61
# 51
# [116, 112, 61, 49]
# 116
# 112
# 61
# 49
# [98, 112, 102, 61, 54]
# 98
# 112
# 102
# 61
# 54
# [102, 116, 120, 45]
# 102
# 116
# 120
# 45
# [118, 99, 45]
# 118
# 99
# 45
# [98, 99, 45]
# 98
# 99
# 45
# [106, 99, 109, 61, 57]
# ...

# %%
sum(l_tt)
# Out:
# 521434
